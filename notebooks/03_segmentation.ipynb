# %%
# This notebook is reserved for customer segmentation
# Segmentation features (RFM) were created in 
# 01_data_cleaning.ipynb as part of feature engineering
# Full K-Means segmentation to be added in future work
